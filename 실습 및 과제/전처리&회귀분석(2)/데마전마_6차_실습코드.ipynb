# %% [markdown]
# #Section 01. 데이터 시각화 소개

# %%
import seaborn as sns
anscombe=sns.load_dataset('anscombe')
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
print(anscombe[anscombe['dataset']=='I']['x'].mean())
print(anscombe[anscombe['dataset']=='II']['x'].mean())
print(anscombe[anscombe['dataset']=='III']['x'].mean())
print(anscombe[anscombe['dataset']=='IV']['x'].mean())
# Out:
# 9.0
# 9.0
# 9.0
# 9.0

# %%
import seaborn as sns
sns.set_theme(style='ticks')
df_anscombe=sns.load_dataset('anscombe')

sns.lmplot(
    data=df_anscombe, x='x', y='y', col='dataset', hue='dataset',
    col_wrap=2, palette='muted', ci=None,
    height=4, scatter_kws={'s': 50, 'alpha': 1})
# Out:
# C:\Users\DO YEON\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Section 02. 차트 시각화 - 맷플롯립

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\do yeon\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\do yeon\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
##1. 선형 차트
### 기본 선형 차트

# %%
from matplotlib import pyplot as plt
years=[1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]
gdp=[300, 543, 1075, 2862, 5979, 10289, 14958, 18320]
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')
plt.title('GDP')
plt.ylabel('$')
plt.show()
plt.savefig('viz_gdp.png')

# %%
### 계열별 선형 차트

# %%
dataset=[[25, 100], [52, 256], [38, 152], [32, 140], [25, 150], [45, 183], [40, 175], [55, 203],
[28, 152], [42, 198]]
actual=[j[1] for j in dataset]
predicted=[115, 242, 176, 148, 115, 209, 185, 256, 129, 195]
error=[(x - y) for x, y in zip(actual, predicted)]
xs=[i for i, _ in enumerate(error)]
plt.plot(xs, actual, 'g-', label='x') # 녹색 실선
plt.plot(xs, predicted, 'r-.', label='y') # 빨간색 점선
plt.plot(xs, error, 'b', label='error') # 파란색 점선
plt.legend(loc=9) # 범례 표시: loc 숫자로 위치 설정
plt.xlabel('mode')
plt.title('actual vs predicted')
plt.show()

# %%
### 그리드 표시

# %%
import matplotlib.pyplot as plt
import numpy as np
dataset=[[25, 100], [52, 256], [38, 152], [32, 140], [25, 150], [45, 183], [40, 175], [55, 203],
[28, 152], [42, 198]]
apt=[i[0] for i in dataset]
kw=[i[-1] for i in dataset]
xpoints=np.array(apt)
ypoints=np.array(kw)
plt.xlabel('apt')
plt.ylabel('kw')
plt.title('apt vs kw')
plt.scatter(xpoints, ypoints)
plt.grid()
plt.show()

# %%
###데이터 강조

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.arange(1, 10, 0.1)
ypoints1=xpoints*0.2
ypoints2=np.sin(xpoints)
plt.plot(xpoints, ypoints1, label='first')
plt.plot(xpoints, ypoints2, label='second')
plt.annotate('annotate', xy=(2, 1), xytext=(4, 1.5), arrowprops={'color':'green'})
plt.show()

# %%
### 하위 차트 표시

# %%
from matplotlib import pyplot as plt
import numpy as np
x=np.arange(1, 10)
y1=x*5
y2=x*1
y3=x*0.3
y4=x*0.2
# 왼쪽 위에 표시
plt.subplot(2, 2, 1)
plt.plot(x, y1)
# 오른쪽 위에 표시
plt.subplot(2, 2, 2)
plt.plot(x, y2)
# 왼쪽 아래 표시
plt.subplot(2, 2, 3)
plt.plot(x, y3)
# 오른쪽 아래 표시
plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
x=np.arange(1, 10)
y1=x*5
y2=x*1
y3=x*0.3
y4=x*0.2
plt.figure(figsize=(20,5))
# 왼쪽 위에 표시
plt.subplot(2, 2, 1)
plt.plot(x, y1)
# 오른쪽 위에 표시
plt.subplot(2, 2, 2)
plt.plot(x, y2)
# 왼쪽 아래 표시
plt.subplot(2, 2, 3)
plt.plot(x, y3)
# 오른쪽 아래 표시
plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.show()

# %%
##2. 막대형 차트, 히스토그램, 산포도, 원형 차트
### 막대형 차트

# %%
from matplotlib import pyplot as plt
movies=['cinema', 'avengers', 'squid game', '007', 'iron man']
score=[5, 10, 3, 8, 9]
plt.bar(movies, score)
plt.ylabel('score')
plt.title('Movies')
plt.xticks([i+0.1 for i, _ in enumerate(movies)], movies) # 0.1에서 막대형 차트 그리기 시작
plt.show()

# %%
plt.barh(movies,score)
plt.ylabel('Movies')
plt.title('score')
plt.yticks([i + 0.1 for i, _ in enumerate(movies)], movies) # 0.1부터 y축 그리기 시작
plt.show()

# %%
plt.bar(movies, score, color='red', width=0.3)
plt.ylabel('score')
plt.title('Movies')
plt.xticks([i + 0.1 for i, _ in enumerate(movies)], movies)
plt.show()

# %%
### 히스토그램

# %%
from collections import Counter
grades=[83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]
histogram=Counter(min(grade // 10 * 10, 90) for grade in grades)
plt.bar([x+5 for x in histogram.keys()], # 오른쪽으로 5만큼 이동해서 그리기 시작
histogram.values(),
10,
edgecolor=(0, 0, 0))
plt.axis([-5, 105, 0, 5]) # x축 범위와 y축 범위 지정
plt.xticks([10 * i for i in range(11)]) # x축 라벨 표시
plt.xlabel('Decile')
plt.ylabel('# of Students')
plt.title('Distribution of Exam 1 Grades')
plt.savefig('viz_grades.png') # 그림 파일 저장

# %%
### 산포도

# %%
from matplotlib import pyplot as plt
height=[175, 170, 162, 171, 186, 175, 166, 169, 189, 178] # x 독립변수
weight=[ 70, 65, 61, 63, 78, 64, 60, 64, 88, 76] # y 종속변수
labels=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'I', 'j']
plt.scatter(height, weight)

# %%
from matplotlib import pyplot as plt
height=[175, 170, 162, 171, 186, 175, 166, 169, 189, 178] # x 독립변수
weight=[70, 65, 61, 63, 78, 64, 60, 64, 88, 76] # y 종속변수
labels=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'I', 'j']
plt.scatter(height, weight)
for i, j, k in zip(labels, height, weight):
  plt.annotate(i,
               xy=(j, k), # 레이블 표시
               xytext=(5, -5), # 텍스트 위치
  textcoords='offset points')
plt.title('height vs. weight')
plt.xlabel('height')
plt.ylabel('weight')
plt.show()

# %%
import matplotlib.pyplot as plt
rat=[55, 15, 14, 16]
insect=['butterflies', 'dragonflies', 'spiders', 'bees']
plt.pie(rat, labels=insect, autopct='%.2f%%')
plt.show()

# %%
import matplotlib.pyplot as plt
rat=[55, 15, 14, 16]
insect=['butterflies', 'dragonflies', 'spiders', 'bees']
colors=['lightpink', 'silver', 'lightblue', 'lightgray']
plt.pie(rat, labels=insect, autopct='%.2f%%', colors=colors)
plt.show()

# %%
import matplotlib.pyplot as plt
rat=[55, 15, 14, 16]
insect=['butterflies', 'dragonflies', 'spiders', 'bees']
colors=['lightpink', 'silver', 'lightblue', 'lightgray']
explode=[0.07, 0.07, 0.07, 0.07]
plt.pie(rat, labels=insect, autopct='%.2f%%', colors=colors, explode=explode, shadow=True)
plt.show()

# %%
import matplotlib.pyplot as plt
rat=[55, 15, 14, 16]
insect=['butterflies', 'dragonflies', 'spiders', 'bees']
colors=['lightpink', 'silver', 'lightblue', 'lightgray']
explode=[0.07, 0.07, 0.07, 0.07]
plt.pie(rat, labels=insect, autopct='%.2f%%', colors=colors, explode=explode, shadow=True)
plt.show()

# %%
# proverb.txt
contents=""" 작은 일에 성실한 사람은 큰일에도 성실하고,
작은 일에 정직하지 못한 사람은 큰일에도 정직하지 못하다.
누가복음 16:10
변함없이 서로 사랑하는 이가 친구이며
위급할 때 서로 돕는 이가 형제다.
잠언 17:17"""
file=open("./proverb.txt", 'w') #mode w
file.write(contents)
file.close()
# hello.txt
file=open("./hello.txt",'a')
while 1:
  content=input()
  if not content: break
  file.write(content+ '\n')
  print(content)
file.close()

# fruits.txt
fruits=["apple","apple","apple","banana","banana","orange","mango","orange","orange","orange"]
index=len(fruits)
file=open("./fruits.txt",'a')
for i in range(len(fruits)):
  if i < (index-1):
    file.write(fruits[i]+'\t')
  else:
    file.write(fruits[i]+'\n')
file.close()
# Out:
# hello.txt
# hello.txt

# %%
import os
import glob
f1=[]
for file in glob.glob('*.txt'):
  with open(file, 'r', encoding='cp949', newline='') as filereader:
    for row in filereader:
      contents=row.split()
      for i in contents:
        contents=i.strip('.').strip(',').strip('')
        f1.append(contents)
f1
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[63], line 6
#       4 for file in glob.glob('*.txt'):
#       5   with open(file, 'r', encoding='cp949', newline='') as filereader:
# ----> 6     for row in filereader:
#       7       contents=row.split()
#       8       for i in contents:
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xaf in position 271: illegal multibyte sequence

# %%
import os
import glob

f1=[]
for file in glob.glob('*.txt'):
  with open(file, 'r', newline='') as filereader:
    for row in filereader:
      contents=row.split()
      for i in contents:
        contents=i.strip('.').strip(',').strip('').strip('를').strip('을').strip("''")
        contents=contents.strip('합니다').strip('하세요')
        contents=contents.strip('에')
        f1.append(contents)
f1
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[64], line 7
#       5 for file in glob.glob('*.txt'):
#       6   with open(file, 'r', newline='') as filereader:
# ----> 7     for row in filereader:
#       8       contents=row.split()
#       9       for i in contents:
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xaf in position 271: illegal multibyte sequence

# %%
##2. 단어의 빈도수 구하기
from collections import Counter
f1
word_counts=Counter(f1)
dict(word_counts)
# word_counts.items()
wc=sorted(word_counts.items(),key=lambda count:count[1], reverse=True)
wc
# Out:
# []

# %%
import pandas as pd
wcdf=pd.DataFrame(wc)
wcdf.columns=['word', 'freq']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 3
#       1 import pandas as pd
#       2 wcdf=pd.DataFrame(wc)
# ----> 3 wcdf.columns=['word', 'freq']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6002, in NDFrame.__setattr__(self, name, value)
#    6000 try:
#    6001     object.__getattribute__(self, name)
# -> 6002     return object.__setattr__(self, name, value)
#    6003 except AttributeError:
#    6004     pass
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:730, in NDFrame._set_axis(self, axis, labels)
#     725 """
#     726 This is called from the cython code when we set the `index` attribute
#     727 directly, e.g. `series.index = [1, 2, 3]`.
#     728 """
#     729 labels = ensure_index(labels)
# --> 730 self._mgr.set_axis(axis, labels)
#     731 self._clear_item_cache()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:225, in BaseBlockManager.set_axis(self, axis, new_labels)
#     223 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     224     # Caller is responsible for ensuring we have an Index object.
# --> 225     self._validate_set_axis(axis, new_labels)
#     226     self.axes[axis] = new_labels
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 2 elements

# %%
wcdf1=wcdf.set_index('word')
wcdf1.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 wcdf1=wcdf.set_index('word')
#       2 wcdf1.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5859, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5856                 missing.append(col)
#    5858 if missing:
# -> 5859     raise KeyError(f"None of {missing} are in the columns")
#    5861 if inplace:
#    5862     frame = self
#
# KeyError: "None of ['word'] are in the columns"

# %%
##3. 워드 클라우드 구현하기

# %%
# !pip install wordcloud
# !pip install konlpy
# Out:
# Requirement already satisfied: wordcloud in c:\users\do yeon\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\do yeon\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\do yeon\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\do yeon\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\do yeon\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\do yeon\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: konlpy in c:\users\do yeon\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\do yeon\anaconda3\lib\site-packages (from konlpy) (1.4.1)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\do yeon\anaconda3\lib\site-packages (from konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in c:\users\do yeon\anaconda3\lib\site-packages (from konlpy) (1.24.3)
# Requirement already satisfied: packaging in c:\users\do yeon\anaconda3\lib\site-packages (from JPype1>=0.7.0->konlpy) (23.1)

# %%
import pandas as pd
import numpy as np
import re
# 한글 표현을 위해 폰트 설치
# %config InlineBackend.figure_format ='retina'
# !apt -qq -y install fonts-nanum > /dev/null
import matplotlib.font_manager as fm
# 나눔바른고딕 사용
fontpath='C:/Windows/Fonts/NanumGothic.ttf'
font=fm.FontProperties(fname=fontpath, size=9)
# Out:
# 지정된 경로를 찾을 수 없습니다.

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

word_freq=wcdf1['freq'].to_dict()
wordcloud=WordCloud(font_path='NanumGothic.ttf', width=1000, height=1000).generate_from_frequencies(word_freq)
plt.imshow(wordcloud)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 4
#       1 import matplotlib.pyplot as plt
#       2 from wordcloud import WordCloud
# ----> 4 word_freq=wcdf1['freq'].to_dict()
#       5 wordcloud=WordCloud(font_path='NanumGothic.ttf', width=1000, height=1000).generate_from_frequencies(word_freq)
#       6 plt.imshow(wordcloud)
#
# NameError: name 'wcdf1' is not defined

# %%
wordcloud=WordCloud(font_path='NanumGothic.ttf', background_color='white', colormap
='autumn').generate_from_frequencies(word_freq)
plt.imshow(wordcloud)
plt.title('Word Frequency', size=13) # 제목 지정
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 2
#       1 wordcloud=WordCloud(font_path='NanumGothic.ttf', background_color='white', colormap
# ----> 2 ='autumn').generate_from_frequencies(word_freq)
#       3 plt.imshow(wordcloud)
#       4 plt.title('Word Frequency', size=13) # 제목 지정
#
# NameError: name 'word_freq' is not defined

# %%
from PIL import Image
import numpy as np
im=Image.open('heart.png') # 이미지 파일 읽어오기
mask_arr=np.array(im) # 픽셀 값 배열 형태 변환
wordcloud=WordCloud(font_path='NanumGothic.ttf', background_color='white', colormap='autumn',width=700,height=700,random_state=43,mask=mask_arr,prefer_horizontal=True).generate_from_frequencies(word_freq)
plt.figure(figsize=(6, 6))
plt.imshow(wordcloud)
plt.title('Word Frequency', size=13)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[73], line 3
#       1 from PIL import Image
#       2 import numpy as np
# ----> 3 im=Image.open('heart.png') # 이미지 파일 읽어오기
#       4 mask_arr=np.array(im) # 픽셀 값 배열 형태 변환
#       5 wordcloud=WordCloud(font_path='NanumGothic.ttf', background_color='white', colormap='autumn',width=700,height=700,random_state=43,mask=mask_arr,prefer_horizontal=True).generate_from_frequencies(word_freq)
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'heart.png'

# %%
# Section 04 지도 데이터 시각화 - 폴리엄

# %%
# !pip install folium
import folium
# Out:
# Collecting folium
#   Obtaining dependency information for folium from https://files.pythonhosted.org/packages/a2/1a/37c7ee1bc806d6c32621fecc72c19f6a9f9b4369e5e8f406a7c16d49f031/folium-0.15.0-py2.py3-none-any.whl.metadata
#   Downloading folium-0.15.0-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting branca>=0.6.0 (from folium)
#   Obtaining dependency information for branca>=0.6.0 from https://files.pythonhosted.org/packages/2f/e7/603b136221de923055716d23e3047da71f92e0d8ba2c4517ce49a54fe768/branca-0.7.0-py3-none-any.whl.metadata
#   Downloading branca-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\do yeon\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\do yeon\anaconda3\lib\site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in c:\users\do yeon\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\do yeon\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\do yeon\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\do yeon\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\do yeon\anaconda3\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\do yeon\anaconda3\lib\site-packages (from requests->folium) (2023.7.22)
# Downloading folium-0.15.0-py2.py3-none-any.whl (100 kB)
#    ---------------------------------------- 0.0/100.3 kB ? eta -:--:--
#    ------------------------ --------------- 61.4/100.3 kB 3.2 MB/s eta 0:00:01
#    ------------------------------------ --- 92.2/100.3 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 100.3/100.3 kB 1.2 MB/s eta 0:00:00
# Downloading branca-0.7.0-py3-none-any.whl (25 kB)
# Installing collected packages: branca, folium
# Successfully installed branca-0.7.0 folium-0.15.0

# %%
# 서울시청 지도 좌표인 위도 37.5662952, 경도 126.9779451인 지점을 location에 추가
foliumMap=folium.Map(location=[37.5662952, 126.9779451], zoom_start=16)
# 지도에서 마커를 표시할 위치를 location 옵션에 위도와 경도로 추가
folium.Marker(location=[37.5662952, 126.9779451]).add_to(foliumMap)
popup=folium.Popup('서울시청위치.', max_width=300)
folium.Marker(location=[37.5662952, 126.9779451], popup=popup).add_to(foliumMap)
foliumMap.save('./foliumMap.html')
foliumMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cd6c71e18a83bd80e8069b097b88e39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cd6c71e18a83bd80e8069b097b88e39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cd6c71e18a83bd80e8069b097b88e39 = L.map(
#                 &quot;map_3cd6c71e18a83bd80e8069b097b88e39&quot;,
#                 {
#                     center: [37.5662952, 126.9779451],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7f4c8455a113a101b4e59e1d4108b26 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_f7f4c8455a113a101b4e59e1d4108b26.addTo(map_3cd6c71e18a83bd80e8069b097b88e39);
#
#             var marker_7b1e404ca03ae4904fb080f8db09dd3c = L.marker(
#                 [37.5662952, 126.9779451],
#                 {}
#             ).addTo(map_3cd6c71e18a83bd80e8069b097b88e39);
#
#
#             var marker_96e901000f606db28a24a68530b89c2c = L.marker(
#                 [37.5662952, 126.9779451],
#                 {}
#             ).addTo(map_3cd6c71e18a83bd80e8069b097b88e39);
#
#
#         var popup_ba366e115057fd91063241498aeb2111 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_fe94a95f617d16eee19499ac865fe9f2 = $(`&lt;div id=&quot;html_fe94a95f617d16eee19499ac865fe9f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울시청위치.&lt;/div&gt;`)[0];
#                 popup_ba366e115057fd91063241498aeb2111.setContent(html_fe94a95f617d16eee19499ac865fe9f2);
#
#
#
#         marker_96e901000f606db28a24a68530b89c2c.bindPopup(popup_ba366e115057fd91063241498aeb2111)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests
import folium
from pandas.io.json import json_normalize
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[76], line 3
#       1 import requests
#       2 import folium
# ----> 3 from pandas.io.json import json_normalize
#
# ImportError: cannot import name 'json_normalize' from 'pandas.io.json' (C:\Users\DO YEON\anaconda3\Lib\site-packages\pandas\io\json\__init__.py)

# %%
targetSite='https://www.starbucks.co.kr/store/getStore.do?r=8K3XF06R9Q'
req=requests.post(targetSite, data={
'ins_lat': 37.563398,
'ins_lng': 126.9863309,
'p_sido_cd': '01',
'p_gugun_cd': '',
'in_biz_cd': '',
'iend': 600,
'set_date': ''
})
starbucks=req.json()
print(type(starbucks))
# Out:
# <class 'dict'>

# %%
starbucks_df=json_normalize(starbucks, 'list')

starbucks_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 starbucks_df=json_normalize(starbucks, 'list')
#       3 starbucks_df
#
# NameError: name 'json_normalize' is not defined

# %%
starbucks_df_map=starbucks_df[['s_name','sido_code','sido_name','gugun_code','gugun_name',
'doro_address','lat','lot']]
starbucks_df_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 starbucks_df_map=starbucks_df[['s_name','sido_code','sido_name','gugun_code','gugun_name',
#       2 'doro_address','lat','lot']]
#       3 starbucks_df_map
#
# NameError: name 'starbucks_df' is not defined

# %%
starbucks_df_map['lat']=starbucks_df_map['lat'].astype(float)
starbucks_df_map['lot']=starbucks_df_map['lot'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 starbucks_df_map['lat']=starbucks_df_map['lat'].astype(float)
#       2 starbucks_df_map['lot']=starbucks_df_map['lot'].astype(float)
#
# NameError: name 'starbucks_df_map' is not defined

# %%
starbucksMap=folium.Map(location=[37.5700249, 126.9836398], zoom_start=17)
popup=folium.Popup('종각점', max_width=300)
folium.Marker(location=[37.569918, 126.984528], popup=popup).add_to(starbucksMap)
popup=folium.Popup('종로관철점', max_width=300)
folium.Marker(location=[37.569058, 126.986013], popup=popup).add_to(starbucksMap)
popup=folium.Popup('종로구청점', max_width=300)
folium.Marker(location=[37.572662, 126.981138], popup=popup).add_to(starbucksMap)
starbucksMap.save('./starMap1.html')
starbucksMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2773b548079ff25c5599ef95e85e51d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2773b548079ff25c5599ef95e85e51d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2773b548079ff25c5599ef95e85e51d9 = L.map(
#                 &quot;map_2773b548079ff25c5599ef95e85e51d9&quot;,
#                 {
#                     center: [37.5700249, 126.9836398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc11abc106fd80628dc3e2a2034d2635 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_dc11abc106fd80628dc3e2a2034d2635.addTo(map_2773b548079ff25c5599ef95e85e51d9);
#
#             var marker_40190036146850ae8e6b59498bf1ffd7 = L.marker(
#                 [37.569918, 126.984528],
#                 {}
#             ).addTo(map_2773b548079ff25c5599ef95e85e51d9);
#
#
#         var popup_f65ebaa985e960af7c2ce67c8f1698e5 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_ef01556cb064690a903d8a3d7ddff620 = $(`&lt;div id=&quot;html_ef01556cb064690a903d8a3d7ddff620&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종각점&lt;/div&gt;`)[0];
#                 popup_f65ebaa985e960af7c2ce67c8f1698e5.setContent(html_ef01556cb064690a903d8a3d7ddff620);
#
#
#
#         marker_40190036146850ae8e6b59498bf1ffd7.bindPopup(popup_f65ebaa985e960af7c2ce67c8f1698e5)
#         ;
#
#
#
#
#             var marker_7d0826cb33c1234aa0db55c3b8b56735 = L.marker(
#                 [37.569058, 126.986013],
#                 {}
#             ).addTo(map_2773b548079ff25c5599ef95e85e51d9);
#
#
#         var popup_03ab6349393995a5f13c0954697e6709 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_f520d79db8eb6fd69f8736c6f2f87997 = $(`&lt;div id=&quot;html_f520d79db8eb6fd69f8736c6f2f87997&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종로관철점&lt;/div&gt;`)[0];
#                 popup_03ab6349393995a5f13c0954697e6709.setContent(html_f520d79db8eb6fd69f8736c6f2f87997);
#
#
#
#         marker_7d0826cb33c1234aa0db55c3b8b56735.bindPopup(popup_03ab6349393995a5f13c0954697e6709)
#         ;
#
#
#
#
#             var marker_8a8044921cafd98c3bf67e872b7b7088 = L.marker(
#                 [37.572662, 126.981138],
#                 {}
#             ).addTo(map_2773b548079ff25c5599ef95e85e51d9);
#
#
#         var popup_a81822db19190f8c083bce8d45350e87 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_72a567676064f0a6cacf61fce80ab91b = $(`&lt;div id=&quot;html_72a567676064f0a6cacf61fce80ab91b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종로구청점&lt;/div&gt;`)[0];
#                 popup_a81822db19190f8c083bce8d45350e87.setContent(html_72a567676064f0a6cacf61fce80ab91b);
#
#
#
#         marker_8a8044921cafd98c3bf67e872b7b7088.bindPopup(popup_a81822db19190f8c083bce8d45350e87)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
